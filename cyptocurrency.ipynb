# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests

# %%
crypto_list = []
for page in range(1,100):
  url=f"https://coinmarketcap.com/?{page}"
  webpage=requests.get(url).text
  rows = soup.find('table', {'class': 'sc-beb003d5-3 ieTeVa cmc-table'}).find('tbody').find_all('tr')
  for row in rows:
    td = row.find_all('td')
    if len(td) >= 10:
      for i in td:
        crypto_list.append(i.get_text())
while("" in crypto_list):
  crypto_list.remove("")

# %%
crypto_list=np.array(crypto_list).reshape(990,9)

# %%
	

columns=["Index","Name","Price","1h %","24h %","7d %","Market Cap","Volume(24h)","Circulating Supply"]
data=pd.DataFrame(data=crypto_list,columns=columns)

# %%
data=data.drop(["Index"],axis=1)

# %%
from google.colab import data_table
data_table.enable_dataframe_formatter()

# %%
data
# Out:
#               Name       Price   1h %  24h %   7d %                Market Cap  \
# 0      Bitcoin1BTC  $28,671.43  0.08%  2.22%  0.22%  $555.00B$554,996,662,671
# 1     Ethereum2ETH   $1,867.00  0.10%  1.93%  0.48%  $224.77B$224,772,860,360
# 2      Tether3USDT       $1.00  0.01%  0.02%  0.00%    $81.90B$81,895,621,948
# 3          BNB4BNB     $323.24  0.01%  0.18%  4.56%    $50.39B$50,390,410,315
# 4    USD Coin5USDC     $0.9999  0.01%  0.00%  0.01%    $30.26B$30,256,707,098
# ..             ...         ...    ...    ...    ...                       ...
# 985        XRP6XRP     $0.4602  0.22%  0.69%  2.32%    $23.82B$23,822,507,342
# 986    Cardano7ADA     $0.3855  0.13%  0.38%  4.09%    $13.42B$13,418,963,416
# 987  Dogecoin8DOGE    $0.07834  0.08%  0.15%  2.74%    $10.90B$10,904,016,936
# 988  Polygon9MATIC     $0.9848  0.67%  2.55%  2.23%      $9.11B$9,108,874,442
# 989    Solana10SOL      $21.78  0.26%  0.51%  1.96%      $8.58B$8,583,632,409
#
# ...

# %%
data.to_csv("CryptoCurrencyData.csv")
